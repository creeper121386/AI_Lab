# %%
from urllib.request import urlopen
import re
from bs4 import BeautifulSoup
import requests

pageNum = 30
localPath = '/run/media/why/DATA/why的程序测试/AI_Lab/DataSet/爬虫_landscape/'

rootURL = 'http://konachan.net/'
url = 'http://konachan.net/post?tags=clouds+landscape'

imgFinder = re.compile(r'.*\.jpg')

# %%
html = urlopen(url).read()
soup = BeautifulSoup(html, features='lxml')
content = soup.find_all('img')
for tag in content:
    match = imgFinder.match(tag['src'])
    if match:
        print(match.group())
# Out:
# https://konachan.net/data/preview/b6/b8/b6b8363bef9067a3fea6ad524a6ea1a3.jpg
# https://konachan.net/data/preview/ee/d3/eed3867f7afa50a33b984a2dd53911dd.jpg
# https://konachan.net/data/preview/c0/3c/c03cf69ed890c3b16d0fef111b486b2d.jpg
# https://konachan.net/data/preview/4d/6b/4d6bead00b642957838f64d30b4decef.jpg
# https://konachan.net/data/preview/83/45/8345b75078f713a4915ce0b12811a509.jpg
# https://konachan.net/data/preview/7c/42/7c42a9164bcfb0fce7c88085f09d9dce.jpg
# https://konachan.net/data/preview/80/99/809959e6416348e3a9a180b356e56a6d.jpg
# https://konachan.net/data/preview/db/7d/db7d98defc522094f4d3321ebafb68b5.jpg
# https://konachan.net/data/preview/7f/c4/7fc4148bce6e4caa32f8210bd5c71e93.jpg
# https://konachan.net/data/preview/c4/24/c42488e01b0780bb1421a1007cee0fac.jpg
# https://konachan.net/data/preview/ca/aa/caaa076308575d859a22aef7f20c37eb.jpg
# https://konachan.net/data/preview/85/2d/852dbc76431f1e58b4225143711fb1b2.jpg
# https://konachan.net/data/preview/52/4c/524c41e3e2c277d444623f36c7c19bc2.jpg
# https://konachan.net/data/preview/23/60/23600f6f34f7b472d3b3afaa651ffb09.jpg
# https://konachan.net/data/preview/9b/80/9b803e9d19e6d39e371f6f5d4ff13ee5.jpg
# https://konachan.net/data/preview/9e/cf/9ecf0ed50baab0da53287104a4069e3a.jpg
# https://konachan.net/data/preview/bd/a5/bda581e41c5a358f5c9fa83ac8a929db.jpg
# https://konachan.net/data/preview/6b/45/6b45edb103320e3b398623495fcf8863.jpg
# https://konachan.net/data/preview/6d/ee/6dee5f7cddd98214e50ae30dc9752cd4.jpg
# https://konachan.net/data/preview/29/ba/29ba57e3003af5bfa9b4b4973c6c4841.jpg
# https://konachan.net/data/preview/6c/55/6c5574b1716de82b397fdde9f94e576c.jpg

# %%
requests.get(rootURL, params={'tags':'landscape'}).content
# Out:
# b'<!DOCTYPE html>\n<html class="action-post action-post-index hide-advanced-editing">\n<head><script type="text/javascript">var NREUMQ=NREUMQ||[];NREUMQ.push(["mark","firstbyte",new Date().getTime()]);</script>\n<meta name="robots" content="none">\n  <meta http-equiv="Content-type" content="text/html;charset=UTF-8">\n  <title>/clouds landscape | konachan.net - Konachan.com Anime Wallpapers</title>\n  <meta name="description" content="Konachan.com - Image board site for Anime / Manga wallpapers. Unlimited and unrestricted downloads.">\n  <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">\n  <link rel="top" title="konachan.net" href="/">\n  <link href="http://konachan.net/post?tags=clouds+landscape" rel="canonical" />\n  <script type="text/javascript">\n    var css = ".javascript-hide { display: none !important; }";\n    var style = document.createElement("style"); style.type = "text/css";\n    if(style.styleSheet) // IE\n      style.styleSheet.cssText = css;\n    else\n      style.appendChild(document.createTextNode(css));\n    document.getElementsByTagName("head")[0].appendChild(style);\n  </script>\n\n    <link href="http://konachan.net/post/piclens?page=1&amp;tags=clouds+landscape" rel="alternate" title="RSS" type="application/rss+xml" />\n  <link href="/post?page=2&amp;tags=clouds+landscape" rel="next" title="Next Page" />\n<link href="/post?page=32&amp;tags=clouds+landscape" rel="last" title="Last Page" />\n\n  <link href="http://konachan.net/post/atom?tags=clouds+landscape" rel="alternate" title="ATOM" type="application/atom+xml" />\n  <link href="/assets/application-10824cb18d32efc10831809ea5f02fad.css" media="screen" rel="stylesheet" />\n\n  <script src="/assets/application-9ad076d8dede6744cfbcc270a8569b50.js"></script>\n  <script src="/assets/moe-legacy/application-ce3dc3e48d9ceff5fb362df103a23576.js"></script>\n  <script type="text/javascript">\n  I18n.defaultLocale = "en";\n  I18n.locale = "en";\n</script>\n\n  <!--[if lt IE 8]>\n  <script src="/IE8.js" type="text/javascript"></script>\n  <![endif]-->\n  <link href="/opensearch.xml" rel="search" title="konachan.net" type="application/opensearchdescription+xml" />\n  \n  <!--[if lt IE 7]>\n    <style type="text/css">\n      body div#post-view > div#right-col > div > div#note-container > div.note-body {\n        overflow: visible;\n      }\n    </style>\n    <script src="http://ie7-js.googlecode.com/svn/trunk/lib/IE7.js" type="text/javascript"></script>\n  <![endif]-->\n  <meta content="authenticity_token" name="csrf-param" />\n<meta content="QFnAas4Gea3hEH3511+kD2OO99Ep20Hh1A5wav5EDTg=" name="csrf-token" />\n</head>\n<body>\n  <div class="overlay-notice-container" id="notice-container" style="display: none;">\n  <table cellspacing=0 cellpadding=0> <tbody>\n    <tr> <td>\n      <div id="notice">\n      </div>\n    </td> </tr>\n  </tbody> </table>\n</div>\n\n      <div id="header">\n    <div id="title"><h2 id="site-title"><a href="https://konachan.net"><img alt="konachan.net" height="75" id="logo" src="/images/logo_small.png" width="484" /></a><span>/<a href="/post?tags=clouds">clouds</a>+<a href="/post?tags=landscape">landscape</a></span></h2></div>\n    <div class="clearfix" id="main-menu" data-controller="post">\n    <ul>\n      <li class="user"><a href="/user/home">My Account</a>\n        <a class="submenu-button" href="#">\xe2\x96\xa0</a>\n        <ul class="submenu">\n            <li><a class="login-button" href="/user/login" id="login-link">Login</a></li>\n            <li><a href="/user/signup"><span class="translation_missing" title="translation missing: en.layouts.menu.account.register">Register</span></a></li>\n            <li><a href="/user/reset_password">Reset Password</a></li>\n        </ul>\n      </li>\n      <li class="post"><a href="/post">Posts</a>\n        <a class="submenu-button" href="#">\xe2\x96\xa0</a>\n        <ul class="search-box">\n          <li>\n            <div>\n              <form accept-charset="UTF-8" action="/post" me ...
